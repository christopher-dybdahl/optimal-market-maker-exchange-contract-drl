# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd "drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl"
# Out:
# /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl

# %%
# %pip install -r requirements.txt
# Out:
# Ignoring appnope: markers 'python_version >= "3.11" and python_version < "3.15" and platform_system == "Darwin"' don't match your environment
# Ignoring cffi: markers 'python_version >= "3.11" and python_version < "3.15" and implementation_name == "pypy"' don't match your environment
# Ignoring colorama: markers 'python_version >= "3.11" and python_version < "3.15" and sys_platform == "win32"' don't match your environment
# Ignoring pycparser: markers 'python_version >= "3.11" and python_version < "3.15" and implementation_name == "pypy"' don't match your environment
# Collecting asttokens==3.0.1 (from -r requirements.txt (line 4))
#   Downloading asttokens-3.0.1-py3-none-any.whl (27 kB)
# Collecting comm==0.2.3 (from -r requirements.txt (line 95))
#   Downloading comm-0.2.3-py3-none-any.whl (7.3 kB)
# Requirement already satisfied: contourpy==1.3.3 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 98)) (1.3.3)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 171)) (12.9.4)
# Collecting cuda-pathfinder==1.3.5 (from -r requirements.txt (line 196))
#   Downloading cuda_pathfinder-1.3.5-py3-none-any.whl (33 kB)
# Requirement already satisfied: cycler==0.12.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 198)) (0.12.1)
# Collecting debugpy==1.8.20 (from -r requirements.txt (line 201))
#   Downloading debugpy-1.8.20-cp312-cp312-manylinux_2_34_x86_64.whl (4.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 141.0 MB/s eta 0:00:00
# Collecting decorator==5.2.1 (from -r requirements.txt (line 232))
#   Downloading decorator-5.2.1-py3-none-any.whl (9.2 kB)
# Collecting executing==2.2.1 (from -r requirements.txt (line 235))
#   Downloading executing-2.2.1-py2.py3-none-any.whl (28 kB)
# Requirement already satisfied: filelock==3.24.3 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 238)) (3.24.3)
# Requirement already satisfied: fonttools==4.61.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 241)) (4.61.1)
# Collecting fsspec==2026.2.0 (from -r requirements.txt (line 292))
#   Downloading fsspec-2026.2.0-py3-none-any.whl (202 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 202.5/202.5 kB 23.3 MB/s eta 0:00:00
# Collecting ipykernel==7.2.0 (from -r requirements.txt (line 295))
#   Downloading ipykernel-7.2.0-py3-none-any.whl (118 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.8/118.8 kB 15.7 MB/s eta 0:00:00
# Collecting ipython-pygments-lexers==1.1.1 (from -r requirements.txt (line 298))
#   Downloading ipython_pygments_lexers-1.1.1-py3-none-any.whl (8.1 kB)
# Collecting ipython==9.10.0 (from -r requirements.txt (line 301))
#   Downloading ipython-9.10.0-py3-none-any.whl (622 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 622.8/622.8 kB 59.8 MB/s eta 0:00:00
# Collecting jedi==0.19.2 (from -r requirements.txt (line 304))
#   Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 101.5 MB/s eta 0:00:00
# Requirement already satisfied: jinja2==3.1.6 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 307)) (3.1.6)
# Collecting jupyter-client==8.8.0 (from -r requirements.txt (line 310))
#   Downloading jupyter_client-8.8.0-py3-none-any.whl (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.4/107.4 kB 13.2 MB/s eta 0:00:00
# Requirement already satisfied: jupyter-core==5.9.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 313)) (5.9.1)
# Requirement already satisfied: kiwisolver==1.4.9 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 316)) (1.4.9)
# Requirement already satisfied: markupsafe==3.0.3 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 418)) (3.0.3)
# Requirement already satisfied: matplotlib-inline==0.2.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 508)) (0.2.1)
# Collecting matplotlib==3.10.8 (from -r requirements.txt (line 511))
#   Downloading matplotlib-3.10.8-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 158.7 MB/s eta 0:00:0000:01
# Requirement already satisfied: mpmath==1.3.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 567)) (1.3.0)
# Requirement already satisfied: nest-asyncio==1.6.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 570)) (1.6.0)
# Collecting networkx==3.6 (from -r requirements.txt (line 573))
#   Downloading networkx-3.6-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 118.3 MB/s eta 0:00:00
# Collecting numpy==2.4.2 (from -r requirements.txt (line 576))
#   Downloading numpy-2.4.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 113.8 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 649)) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 653)) (12.8.90)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 657)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 661)) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 665)) (9.10.2.21)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 669)) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 673)) (1.13.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 676)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 680)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 684)) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 688)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 692)) (2.27.5)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 695)) (12.8.93)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 699)) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 702)) (12.8.90)
# Requirement already satisfied: packaging==26.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 706)) (26.0)
# Requirement already satisfied: parso==0.8.6 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 709)) (0.8.6)
# Requirement already satisfied: pexpect==4.9.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 712)) (4.9.0)
# Collecting pillow==12.1.1 (from -r requirements.txt (line 715))
#   Downloading pillow-12.1.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 159.8 MB/s eta 0:00:0000:01
# Requirement already satisfied: platformdirs==4.9.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 807)) (4.9.2)
# Requirement already satisfied: prompt-toolkit==3.0.52 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 810)) (3.0.52)
# Collecting psutil==7.2.2 (from -r requirements.txt (line 813))
#   Downloading psutil-7.2.2-cp36-abi3-manylinux2010_x86_64.manylinux_2_12_x86_64.manylinux_2_28_x86_64.whl (155 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.6/155.6 kB 20.5 MB/s eta 0:00:00
# Requirement already satisfied: ptyprocess==0.7.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 835)) (0.7.0)
# Collecting pure-eval==0.2.3 (from -r requirements.txt (line 838))
#   Downloading pure_eval-0.2.3-py3-none-any.whl (11 kB)
# Requirement already satisfied: pygments==2.19.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 844)) (2.19.2)
# Requirement already satisfied: pyparsing==3.3.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 847)) (3.3.2)
# Requirement already satisfied: python-dateutil==2.9.0.post0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 850)) (2.9.0.post0)
# Collecting pyzmq==27.1.0 (from -r requirements.txt (line 853))
#   Downloading pyzmq-27.1.0-cp312-abi3-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl (840 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 841.0/841.0 kB 64.6 MB/s eta 0:00:00
# Collecting setuptools==82.0.0 (from -r requirements.txt (line 946))
#   Downloading setuptools-82.0.0-py3-none-any.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 77.1 MB/s eta 0:00:00
# Requirement already satisfied: six==1.17.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 949)) (1.17.0)
# Collecting stack-data==0.6.3 (from -r requirements.txt (line 952))
#   Downloading stack_data-0.6.3-py3-none-any.whl (24 kB)
# Requirement already satisfied: sympy==1.14.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 955)) (1.14.0)
# Requirement already satisfied: torch==2.10.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 958)) (2.10.0+cu128)
# Collecting tornado==6.5.4 (from -r requirements.txt (line 991))
#   Downloading tornado-6.5.4-cp39-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (445 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 445.3/445.3 kB 48.0 MB/s eta 0:00:00
# Collecting traitlets==5.14.3 (from -r requirements.txt (line 1004))
#   Downloading traitlets-5.14.3-py3-none-any.whl (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.4/85.4 kB 11.8 MB/s eta 0:00:00
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 1007)) (3.6.0)
# Requirement already satisfied: typing-extensions==4.15.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 1022)) (4.15.0)
# Requirement already satisfied: wcwidth==0.6.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 1025)) (0.6.0)
# Installing collected packages: pure-eval, traitlets, tornado, setuptools, pyzmq, psutil, pillow, numpy, networkx, jedi, ipython-pygments-lexers, fsspec, executing, decorator, debugpy, cuda-pathfinder, comm, asttokens, stack-data, matplotlib, jupyter-client, ipython, ipykernel
#   Attempting uninstall: traitlets
#     Found existing installation: traitlets 5.7.1
#     Uninstalling traitlets-5.7.1:
#       Successfully uninstalled traitlets-5.7.1
#   Attempting uninstall: tornado
#     Found existing installation: tornado 6.5.1
#     Uninstalling tornado-6.5.1:
#       Successfully uninstalled tornado-6.5.1
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 75.2.0
#     Uninstalling setuptools-75.2.0:
#       Successfully uninstalled setuptools-75.2.0
#   Attempting uninstall: pyzmq
#     Found existing installation: pyzmq 26.2.1
#     Uninstalling pyzmq-26.2.1:
#       Successfully uninstalled pyzmq-26.2.1
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.9.5
#     Uninstalling psutil-5.9.5:
#       Successfully uninstalled psutil-5.9.5
#   Attempting uninstall: pillow
#     Found existing installation: pillow 11.3.0
#     Uninstalling pillow-11.3.0:
#       Successfully uninstalled pillow-11.3.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.6.1
#     Uninstalling networkx-3.6.1:
#       Successfully uninstalled networkx-3.6.1
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.0
#     Uninstalling fsspec-2025.3.0:
#       Successfully uninstalled fsspec-2025.3.0
#   Attempting uninstall: decorator
#     Found existing installation: decorator 4.4.2
#     Uninstalling decorator-4.4.2:
#       Successfully uninstalled decorator-4.4.2
#   Attempting uninstall: debugpy
#     Found existing installation: debugpy 1.8.15
#     Uninstalling debugpy-1.8.15:
#       Successfully uninstalled debugpy-1.8.15
#   Attempting uninstall: cuda-pathfinder
#     Found existing installation: cuda-pathfinder 1.4.0
#     Uninstalling cuda-pathfinder-1.4.0:
#       Successfully uninstalled cuda-pathfinder-1.4.0
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.10.0
#     Uninstalling matplotlib-3.10.0:
#       Successfully uninstalled matplotlib-3.10.0
#   Attempting uninstall: jupyter-client
#     Found existing installation: jupyter_client 7.4.9
#     Uninstalling jupyter_client-7.4.9:
#       Successfully uninstalled jupyter_client-7.4.9
#   Attempting uninstall: ipython
#     Found existing installation: ipython 7.34.0
#     Uninstalling ipython-7.34.0:
#       Successfully uninstalled ipython-7.34.0
#   Attempting uninstall: ipykernel
#     Found existing installation: ipykernel 6.17.1
#     Uninstalling ipykernel-6.17.1:
#       Successfully uninstalled ipykernel-6.17.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires ipykernel==6.17.1, but you have ipykernel 7.2.0 which is incompatible.
# google-colab 1.0.0 requires ipython==7.34.0, but you have ipython 9.10.0 which is incompatible.
# google-colab 1.0.0 requires tornado==6.5.1, but you have tornado 6.5.4 which is incompatible.
# jupyter-kernel-gateway 2.5.2 requires jupyter-client<8.0,>=5.2.0, but you have jupyter-client 8.8.0 which is incompatible.
# datasets 4.0.0 requires fsspec[http]<=2025.3.0,>=2023.1.0, but you have fsspec 2026.2.0 which is incompatible.
# moviepy 1.0.3 requires decorator<5.0,>=4.0.2, but you have decorator 5.2.1 which is incompatible.
# tensorflow 2.19.0 requires numpy<2.2.0,>=1.26.0, but you have numpy 2.4.2 which is incompatible.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2026.2.0 which is incompatible.
# gradio 5.50.0 requires pillow<12.0,>=8.0, but you have pillow 12.1.1 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.4.2 which is incompatible.
# notebook 6.5.7 requires jupyter-client<8,>=5.3.4, but you have jupyter-client 8.8.0 which is incompatible.
# Successfully installed asttokens-3.0.1 comm-0.2.3 cuda-pathfinder-1.3.5 debugpy-1.8.20 decorator-5.2.1 executing-2.2.1 fsspec-2026.2.0 ipykernel-7.2.0 ipython-9.10.0 ipython-pygments-lexers-1.1.1 jedi-0.19.2 jupyter-client-8.8.0 matplotlib-3.10.8 networkx-3.6 numpy-2.4.2 pillow-12.1.1 psutil-7.2.2 pure-eval-0.2.3 pyzmq-27.1.0 setuptools-82.0.0 stack-data-0.6.3 tornado-6.5.4 traitlets-5.14.3

# %%
# %pip install -e . # Install the project in editable mode
# Out:
# Obtaining file:///content/drive/My%20Drive/GoogleColab/optimal-market-maker-exchange-contract-drl
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: ipykernel<8.0.0,>=7.2.0 in /usr/local/lib/python3.12/dist-packages (from optimal-market-maker-exchange-contract-drl==0.1.0) (7.2.0)
# Requirement already satisfied: matplotlib<4.0.0,>=3.10.8 in /usr/local/lib/python3.12/dist-packages (from optimal-market-maker-exchange-contract-drl==0.1.0) (3.10.8)
# Requirement already satisfied: numpy<3.0.0,>=2.4.2 in /usr/local/lib/python3.12/dist-packages (from optimal-market-maker-exchange-contract-drl==0.1.0) (2.4.2)
# Requirement already satisfied: torch<3.0.0,>=2.10.0 in /usr/local/lib/python3.12/dist-packages (from optimal-market-maker-exchange-contract-drl==0.1.0) (2.10.0+cu128)
# Requirement already satisfied: comm>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel<8.0.0,>=7.2.0->optimal-market-maker-exchange-contract-drl==0.1.0) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /usr/local/lib/python3.12/dist-packages (from ipykernel<8.0.0,>=7.2.0->optimal-market-maker-exchange-contract-drl==0.1.0) (1.8.20)
# Requirement already satisfied: ipython>=7.23.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel<8.0.0,>=7.2.0->optimal-market-maker-exchange-contract-drl==0.1.0) (9.10.0)
# Requirement already satisfied: jupyter-client>=8.8.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel<8.0.0,>=7.2.0->optimal-market-maker-exchange-contract-drl==0.1.0) (8.8.0)
# Requirement already satisfied: jupyter-core!=6.0.*,>=5.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel<8.0.0,>=7.2.0->optimal-market-maker-exchange-contract-drl==0.1.0) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel<8.0.0,>=7.2.0->optimal-market-maker-exchange-contract-drl==0.1.0) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in /usr/local/lib/python3.12/dist-packages (from ipykernel<8.0.0,>=7.2.0->optimal-market-maker-exchange-contract-drl==0.1.0) (1.6.0)
# Requirement already satisfied: packaging>=22 in /usr/local/lib/python3.12/dist-packages (from ipykernel<8.0.0,>=7.2.0->optimal-market-maker-exchange-contract-drl==0.1.0) (26.0)
# Requirement already satisfied: psutil>=5.7 in /usr/local/lib/python3.12/dist-packages (from ipykernel<8.0.0,>=7.2.0->optimal-market-maker-exchange-contract-drl==0.1.0) (7.2.2)
# Requirement already satisfied: pyzmq>=25 in /usr/local/lib/python3.12/dist-packages (from ipykernel<8.0.0,>=7.2.0->optimal-market-maker-exchange-contract-drl==0.1.0) (27.1.0)
# Requirement already satisfied: tornado>=6.4.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel<8.0.0,>=7.2.0->optimal-market-maker-exchange-contract-drl==0.1.0) (6.5.4)
# Requirement already satisfied: traitlets>=5.4.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel<8.0.0,>=7.2.0->optimal-market-maker-exchange-contract-drl==0.1.0) (5.14.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0.0,>=3.10.8->optimal-market-maker-exchange-contract-drl==0.1.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0.0,>=3.10.8->optimal-market-maker-exchange-contract-drl==0.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0.0,>=3.10.8->optimal-market-maker-exchange-contract-drl==0.1.0) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0.0,>=3.10.8->optimal-market-maker-exchange-contract-drl==0.1.0) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0.0,>=3.10.8->optimal-market-maker-exchange-contract-drl==0.1.0) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0.0,>=3.10.8->optimal-market-maker-exchange-contract-drl==0.1.0) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0.0,>=3.10.8->optimal-market-maker-exchange-contract-drl==0.1.0) (2.9.0.post0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.10.0->optimal-market-maker-exchange-contract-drl==0.1.0) (3.24.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.10.0->optimal-market-maker-exchange-contract-drl==0.1.0) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.10.0->optimal-market-maker-exchange-contract-drl==0.1.0) (82.0.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.10.0->optimal-market-maker-exchange-contract-drl==0.1.0) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.10.0->optimal-market-maker-exchange-contract-drl==0.1.0) (3.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.10.0->optimal-market-maker-exchange-contract-drl==0.1.0) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.10.0->optimal-market-maker-exchange-contract-drl==0.1.0) (2026.2.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.10.0->optimal-market-maker-exchange-contract-drl==0.1.0) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.10.0->optimal-market-maker-exchange-contract-drl==0.1.0) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.10.0->optimal-market-maker-exchange-contract-drl==0.1.0) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.10.0->optimal-market-maker-exchange-contract-drl==0.1.0) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.10.0->optimal-market-maker-exchange-contract-drl==0.1.0) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.10.0->optimal-market-maker-exchange-contract-drl==0.1.0) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.10.0->optimal-market-maker-exchange-contract-drl==0.1.0) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.10.0->optimal-market-maker-exchange-contract-drl==0.1.0) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.10.0->optimal-market-maker-exchange-contract-drl==0.1.0) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.10.0->optimal-market-maker-exchange-contract-drl==0.1.0) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.10.0->optimal-market-maker-exchange-contract-drl==0.1.0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.10.0->optimal-market-maker-exchange-contract-drl==0.1.0) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.10.0->optimal-market-maker-exchange-contract-drl==0.1.0) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.10.0->optimal-market-maker-exchange-contract-drl==0.1.0) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.10.0->optimal-market-maker-exchange-contract-drl==0.1.0) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.10.0->optimal-market-maker-exchange-contract-drl==0.1.0) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.10.0->optimal-market-maker-exchange-contract-drl==0.1.0) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch<3.0.0,>=2.10.0->optimal-market-maker-exchange-contract-drl==0.1.0) (1.3.5)
# Requirement already satisfied: decorator>=4.3.2 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel<8.0.0,>=7.2.0->optimal-market-maker-exchange-contract-drl==0.1.0) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel<8.0.0,>=7.2.0->optimal-market-maker-exchange-contract-drl==0.1.0) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel<8.0.0,>=7.2.0->optimal-market-maker-exchange-contract-drl==0.1.0) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel<8.0.0,>=7.2.0->optimal-market-maker-exchange-contract-drl==0.1.0) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel<8.0.0,>=7.2.0->optimal-market-maker-exchange-contract-drl==0.1.0) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel<8.0.0,>=7.2.0->optimal-market-maker-exchange-contract-drl==0.1.0) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel<8.0.0,>=7.2.0->optimal-market-maker-exchange-contract-drl==0.1.0) (0.6.3)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core!=6.0.*,>=5.1->ipykernel<8.0.0,>=7.2.0->optimal-market-maker-exchange-contract-drl==0.1.0) (4.9.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib<4.0.0,>=3.10.8->optimal-market-maker-exchange-contract-drl==0.1.0) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3.0.0,>=2.10.0->optimal-market-maker-exchange-contract-drl==0.1.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<3.0.0,>=2.10.0->optimal-market-maker-exchange-contract-drl==0.1.0) (3.0.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.18.1->ipython>=7.23.1->ipykernel<8.0.0,>=7.2.0->optimal-market-maker-exchange-contract-drl==0.1.0) (0.8.6)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel<8.0.0,>=7.2.0->optimal-market-maker-exchange-contract-drl==0.1.0) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel<8.0.0,>=7.2.0->optimal-market-maker-exchange-contract-drl==0.1.0) (0.6.0)
# Requirement already satisfied: executing>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel<8.0.0,>=7.2.0->optimal-market-maker-exchange-contract-drl==0.1.0) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel<8.0.0,>=7.2.0->optimal-market-maker-exchange-contract-drl==0.1.0) (3.0.1)
# Requirement already satisfied: pure-eval in /usr/local/lib/python3.12/dist-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel<8.0.0,>=7.2.0->optimal-market-maker-exchange-contract-drl==0.1.0) (0.2.3)
# Building wheels for collected packages: optimal-market-maker-exchange-contract-drl
#   Building editable for optimal-market-maker-exchange-contract-drl (pyproject.toml) ... done
#   Created wheel for optimal-market-maker-exchange-contract-drl: filename=optimal_market_maker_exchange_contract_drl-0.1.0-py3-none-any.whl size=2005 sha256=9f3abfec5223966adf29d19c8e1437506dc2aa8a920ec69593d328e46ca57578
#   Stored in directory: /tmp/pip-ephem-wheel-cache-0aztpant/wheels/52/a2/0f/609af876e26ff3abe3b177b2a45cb08bfb4f744271076c0824
# Successfully built optimal-market-maker-exchange-contract-drl
# Installing collected packages: optimal-market-maker-exchange-contract-drl
#   Attempting uninstall: optimal-market-maker-exchange-contract-drl
#     Found existing installation: optimal-market-maker-exchange-contract-drl 0.1.0
#     Uninstalling optimal-market-maker-exchange-contract-drl-0.1.0:
#       Successfully uninstalled optimal-market-maker-exchange-contract-drl-0.1.0
# Successfully installed optimal-market-maker-exchange-contract-drl-0.1.0

# %%
# !python ./scripts/train_mm.py --train --model_name 0.05
# Out:
# ======================================================================
# Run configuration
#   device        : cuda
#   batch_size    : 4096
#   model_name    : '0.05'
#   train         : True
#   load_if_exists: False (will start from scratch)
#   epochs        : 100000
#   lr            : 0.0001
#   save_per      : 10000
#   log_per       : 1000
# ======================================================================
# Loading market config from (config/) /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/config/market_cfg.json
# Market params:
#   A (lit, dark)      : [5000.0, 3000.0]
#   c (theta/sigma)    : [1.5, 1.5]
#   Gamma (lit, dark)  : [9.999999747378752e-05, 4.999999873689376e-05]
#   sigma              : 0.1
#   tick_size          : 0.05
#   half_tick          : 0.025
#   eps                : 1e-08
# ======================================================================
# Loading market maker config from (config/) /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/config/market_maker_cfg.json
# load_if_exists=False - starting from scratch
# ======================================================================
# Saving configuration files...
# Configuration saved to /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model
# ======================================================================
# Training
# Training epochs 1 -> 100000 (lr=0.0001, B=4096)
#   New best model (loss=-8923.501953) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-8962.732422) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-8976.862305) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-8981.800781) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-9032.849609) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-9055.530273) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-9097.440430) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-9115.290039) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-9164.345703) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-9172.828125) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-9220.464844) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-9266.378906) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-9283.685547) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-9342.938477) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-9350.125977) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-9396.032227) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-9430.175781) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-9450.746094) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-9472.949219) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-9505.906250) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-9509.315430) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-9521.576172) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-9529.821289) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-9546.241211) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-9573.894531) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-9585.194336) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-9600.833984) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-9602.983398) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-9647.231445) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-9655.234375) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-9674.694336) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-9675.152344) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-9678.912109) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-9679.176758) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-9703.888672) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-9708.115234) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-9738.051758) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-9795.626953) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-9839.972656) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-9879.228516) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-9881.218750) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-9895.925781) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-9953.992188) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-9956.630859) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-9992.007812) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-10001.873047) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-10014.778320) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-10027.174805) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-10051.017578) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-10053.289062) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-10061.021484) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-10074.266602) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-10174.287109) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-10227.435547) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-10242.655273) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-10295.190430) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-10308.011719) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-10312.241211) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-10329.804688) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-10386.621094) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-10451.278320) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-10511.716797) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-10520.273438) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-10581.402344) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   Epoch   1000/100000 | loss: -10400.445312
#   New best model (loss=-10595.086914) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-10624.672852) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-10640.921875) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-10679.057617) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-10686.849609) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-10703.849609) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-10716.874023) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-10762.681641) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-10778.492188) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-10784.562500) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-10785.657227) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-10830.178711) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-10856.871094) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-10886.449219) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-10895.967773) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-10912.247070) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-10927.554688) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-10962.923828) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-10992.355469) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   Epoch   2000/100000 | loss: -10685.271484
#   New best model (loss=-10996.134766) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-11038.501953) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-11081.928711) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-11088.648438) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-11106.382812) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-11112.955078) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-11127.973633) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   Epoch   3000/100000 | loss: -10990.809570
#   New best model (loss=-11201.191406) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-11201.611328) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-11215.228516) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-11222.139648) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-11238.134766) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-11254.748047) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   Epoch   4000/100000 | loss: -11046.188477
#   New best model (loss=-11298.666992) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   Epoch   5000/100000 | loss: -11111.152344
#   New best model (loss=-11301.798828) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-11312.848633) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   New best model (loss=-11317.261719) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   Epoch   6000/100000 | loss: -11023.544922
#   New best model (loss=-11337.226562) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   Epoch   7000/100000 | loss: -11045.500000
#   New best model (loss=-11386.035156) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   Epoch   8000/100000 | loss: -11221.187500
#   Epoch   9000/100000 | loss: -10991.220703
#   Epoch  10000/100000 | loss: -11058.494141
#   Checkpoint saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/checkpoint_epoch_10000.pt
#   Epoch  11000/100000 | loss: -11212.816406
#   New best model (loss=-11407.793945) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   Epoch  12000/100000 | loss: -11195.466797
#   Epoch  13000/100000 | loss: -11200.378906
#   Epoch  14000/100000 | loss: -11278.501953
#   New best model (loss=-11412.874023) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   Epoch  15000/100000 | loss: -11148.177734
#   Epoch  16000/100000 | loss: -11048.806641
#   Epoch  17000/100000 | loss: -11132.246094
#   Epoch  18000/100000 | loss: -11155.190430
#   New best model (loss=-11441.718750) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   Epoch  19000/100000 | loss: -11119.687500
#   New best model (loss=-11464.642578) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   Epoch  20000/100000 | loss: -11249.384766
#   Checkpoint saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/checkpoint_epoch_20000.pt
#   Epoch  21000/100000 | loss: -11166.480469
#   New best model (loss=-11507.969727) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   Epoch  22000/100000 | loss: -11077.179688
#   Epoch  23000/100000 | loss: -11147.323242
#   Epoch  24000/100000 | loss: -11152.046875
#   Epoch  25000/100000 | loss: -11263.005859
#   Epoch  26000/100000 | loss: -11132.027344
#   Epoch  27000/100000 | loss: -11264.619141
#   Epoch  28000/100000 | loss: -11249.213867
#   Epoch  29000/100000 | loss: -11151.443359
#   Epoch  30000/100000 | loss: -11116.189453
#   Checkpoint saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/checkpoint_epoch_30000.pt
#   Epoch  31000/100000 | loss: -11161.347656
#   Epoch  32000/100000 | loss: -11185.833984
#   Epoch  33000/100000 | loss: -11119.767578
#   Epoch  34000/100000 | loss: -11232.391602
#   Epoch  35000/100000 | loss: -11189.433594
#   Epoch  36000/100000 | loss: -11117.829102
#   Epoch  37000/100000 | loss: -11284.355469
#   Epoch  38000/100000 | loss: -11203.400391
#   New best model (loss=-11541.238281) saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/best_model.pt
#   Epoch  39000/100000 | loss: -11200.846680
#   Epoch  40000/100000 | loss: -11177.697266
#   Checkpoint saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/checkpoint_epoch_40000.pt
#   Epoch  41000/100000 | loss: -11215.722656
#   Epoch  42000/100000 | loss: -11177.731445
#   Epoch  43000/100000 | loss: -11276.613281
#   Epoch  44000/100000 | loss: -11338.062500
#   Epoch  45000/100000 | loss: -11184.134766
#   Epoch  46000/100000 | loss: -11156.768555
#   Epoch  47000/100000 | loss: -11170.443359
#   Epoch  48000/100000 | loss: -11233.405273
#   Epoch  49000/100000 | loss: -11222.176758
#   Epoch  50000/100000 | loss: -11228.230469
#   Checkpoint saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/checkpoint_epoch_50000.pt
#   Epoch  51000/100000 | loss: -11135.061523
#   Epoch  52000/100000 | loss: -11118.788086
#   Epoch  53000/100000 | loss: -11188.541016
#   Epoch  54000/100000 | loss: -11174.107422
#   Epoch  55000/100000 | loss: -11206.352539
#   Epoch  56000/100000 | loss: -11176.207031
#   Epoch  57000/100000 | loss: -11121.175781
#   Epoch  58000/100000 | loss: -11244.380859
#   Epoch  59000/100000 | loss: -11056.347656
#   Epoch  60000/100000 | loss: -11042.647461
#   Checkpoint saved -> /content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/saved_models/market_maker/0.05_model/checkpoint_epoch_60000.pt
#   Epoch  61000/100000 | loss: -11299.860352
#   Epoch  62000/100000 | loss: -11222.828125
#   Epoch  63000/100000 | loss: -11161.718750
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/GoogleColab/optimal-market-maker-exchange-contract-drl/./scripts/train_mm.py", line 208, in <module>
#     main()
#   File "/content/drive/MyDrive/GoogleColab/optimal-market-maker-exchange-contract-drl/./scripts/train_mm.py", line 181, in main
#     all_losses, best_loss = mm.fit(
#                             ^^^^^^^
#   File "/content/drive/My Drive/GoogleColab/optimal-market-maker-exchange-contract-drl/src/optimal_market_maker_exchange_contract_drl/agent.py", line 316, in fit
#     loss.backward()
#   File "/usr/local/lib/python3.12/dist-packages/torch/_tensor.py", line 630, in backward
#     torch.autograd.backward(
#   File "/usr/local/lib/python3.12/dist-packages/torch/autograd/__init__.py", line 364, in backward
#     _engine_run_backward(
#   File "/usr/local/lib/python3.12/dist-packages/torch/autograd/graph.py", line 865, in _engine_run_backward
#     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
